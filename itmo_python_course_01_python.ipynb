# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariya93/2023_2024-cloud-platforms-as-the-basis-of-technology-entrepreneurship-U4125-Konstantinidi_m_g/blob/main/itmo_python_course_01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Вывод текста на экран

# %%
print('Привет мир!')
# Out:
# Привет мир!

# %%
var = 'мир!'

# Вызов функции print с аргументами
print('Привет', var)
print('Привет' + ' ' + var)
print(f'Привет {var}')
# Out:
# Привет мир!
# Привет мир!
# Привет мир!

# %% [markdown]
# ### Переменные и типы данных

# %% [markdown]
# #### Строки

# %%
var = 'мир!'
var_1 = 'Привет' + ' ' + var
var_1
# Out:
# 'Привет мир!'

# %%
var_1 += ' Всем привет!'
var_1
# Out:
# 'Привет мир! Всем привет!'

# %% [markdown]
# Строки можно еще и "умножать"

# %%
'Привет! ' * 3
# Out:
# 'Привет! Привет! Привет! '

# %% [markdown]
# #### Проверка типа объекта в python

# %%
type(var_1)
# Out:
# str

# %% [markdown]
# #### Числа

# %% [markdown]
# С переменными, которые содержат числа, можно проводить арифметические операции

# %%
total_books = 25
total_books += 10
total_books
# Out:
# 35

# %%
total_books_1 = total_books - 25 * 10
total_books_1
# Out:
# -215

# %%
type(total_books_1)
# Out:
# int

# %% [markdown]
# Что если сложить строку и число?

# %%
total_books_1 + '5'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b726830e3bb1> in <cell line: 1>()
# ----> 1 total_books_1 + '5'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Типы могут меняться в процессе вычислений

# %%
div_result = total_books_1 / 2
div_result
# Out:
# -107.5

# %%
type(div_result)
# Out:
# float

# %% [markdown]
# Или мы можем их менять сами

# %%
num = 100
type(num)
# Out:
# int

# %%
num_str = str(100)
type(num_str)
# Out:
# str

# %%
num_str
# Out:
# '100'

# %%
num + num_str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c2b25047cd7d> in <cell line: 1>()
# ----> 1 num + num_str
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num_str = int(num_str)
num + num_str
# Out:
# 200

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-233884bacd4e> in <cell line: 1>()
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# #### Логические значения

# %%
num_str
# Out:
# 100

# %%
is_str = type(num_str) is str
is_str
# Out:
# False

# %%
is_str = type(num_str) is int
is_str
# Out:
# True

# %%
type(is_str)
# Out:
# bool

# %%
is_str = not is_str
is_str
# Out:
# False

# %% [markdown]
# #### Списки

# %%
weather = [25, 23, 20, 29]
type(weather)
# Out:
# list

# %%
weather
# Out:
# [25, 23, 20, 29]

# %% [markdown]
# Можно обращаться к любому элементу списка по индексу

# %%
print(weather[0])
print(weather[3])
# Out:
# 25
# 29

# %%
len(weather)
# Out:
# 4

# %%
weather[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-48e5bb03706a> in <cell line: 1>()
# ----> 1 weather[10]
#
# IndexError: list index out of range

# %% [markdown]
# Элементы изменяемы

# %%
weather[0] = 26
weather
# Out:
# [26, 23, 20, 29]

# %% [markdown]
# [Списки (list). Функции и методы списков](https://pythonworld.ru/tipy-dannyx-v-python/spiski-list-funkcii-i-metody-spiskov.html)

# %%
weather.append(31) # добавление элемента в конец списка
weather
# Out:
# [26, 23, 20, 29, 31]

# %%
weather.insert(1, 24) # вставка элемента по индексу
weather
# Out:
# [26, 24, 23, 20, 29, 31]

# %%
weather.append(24)
print(weather)
weather.index(24) # индекс первого элемента с заданным значением
# Out:
# [26, 24, 23, 20, 29, 31, 24]
# 1

# %%
weather.append('29')
weather
# Out:
# [26, 24, 23, 20, 29, 31, 24, '29']

# %% [markdown]
# #### Кортежи

# %%
weather = (25, 23, 20, 29)
type(weather)
# Out:
# tuple

# %%
weather
# Out:
# (25, 23, 20, 29)

# %%
print(weather[0])
print(weather[3])
# Out:
# 25
# 29

# %% [markdown]
# Кортежи - неизменяемый тип данных!

# %%
weather[0] = 26
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3c2d01c82301> in <cell line: 1>()
# ----> 1 weather[0] = 26
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Кортежи поддерживают все операции над списками, не изменяющие список (сложение, умножение на число, методы `index()` и `count()` и некоторые другие операции)

# %% [markdown]
# Зачем нужны кортежи, если есть списки?
#
# - Кортеж защищен от изменений, как намеренных (что плохо), так и случайных (что хорошо).
# - Меньший размер (список — изменяемая последовательность. Это означает, что в него можно добавлять новые элементы. Из-за этого Python приходится выделять для списка больше памяти, чем нужно.)

# %%
a = (1, 2, 3, 4, 5, 6)
b = [1, 2, 3, 4, 5, 6]

# %%
a.__sizeof__() # возвращает размер объекта в байтах
# Out:
# 72

# %%
b.__sizeof__()
# Out:
# 88

# %% [markdown]
# #### Словари

# %% [markdown]
# Неупорядоченные коллекции произвольных объектов с доступом по ключу.

# %%
weather = {
    'Понедельник': 25,
    'Вторник': 23,
    'Среда': 20,
    'Четверг': 29
}
type(weather)
# Out:
# dict

# %%
weather
# Out:
# {'Понедельник': 25, 'Вторник': 23, 'Среда': 20, 'Четверг': 29}

# %% [markdown]
# Можно обращаться к элементам словаря по ключу

# %%
weather['Понедельник']
# Out:
# 25

# %%
weather['Понедельник'] = 26
weather['Понедельник']
# Out:
# 26

# %% [markdown]
# Ключи могут быть разных типов

# %%
weather[123] = 456
weather
# Out:
# {'Понедельник': 26, 'Вторник': 23, 'Среда': 20, 'Четверг': 29, 123: 456}

# %%
weather[[1, 2, 3]] = 'list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-390ba9f502d2> in <cell line: 1>()
# ----> 1 weather[[1, 2, 3]] = 'list'
#
# TypeError: unhashable type: 'list'

# %%
weather[(1, 2, 3)] = 'tuple'
weather
# Out:
# {'Понедельник': 26,
#  'Вторник': 23,
#  'Среда': 20,
#  'Четверг': 29,
#  123: 456,
#  (1, 2, 3): 'tuple'}

# %% [markdown]
# [Словари (dict) и работа с ними. Методы словарей](https://pythonworld.ru/tipy-dannyx-v-python/slovari-dict-funkcii-i-metody-slovarej.html)

# %%
for item in weather.values():
  print(item)
# Out:
# 26
# 23
# 20
# 29
# 456
# tuple

# %%
for item in weather.keys():
  print(item)
# Out:
# Понедельник
# Вторник
# Среда
# Четверг
# 123
# (1, 2, 3)

# %%
for k, v in weather.items():
  print(f'{k}: {v}')
# Out:
# Понедельник: 26
# Вторник: 23
# Среда: 20
# Четверг: 29
# 123: 456
# (1, 2, 3): tuple

# %% [markdown]
# #### Множества

# %%
set_1 = {'a', 'b', 'c', 'd'}
set_1
# Out:
# {'a', 'b', 'c', 'd'}

# %%
set_2 = {'a', 'b', 'c', 'd', 'a', 'b', 'a'}
set_2
# Out:
# {'a', 'b', 'c', 'd'}

# %%
set_1 == set_2
# Out:
# True

# %% [markdown]
# Множества удобно использовать для удаления повторяющихся элементов

# %%
letters = ['a', 'b', 'c', 'd', 'a', 'b', 'a']
letters = set(letters)
letters
# Out:
# {'a', 'b', 'c', 'd'}

# %%
letters.add('e')
letters
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %% [markdown]
# `set` - изменяемый тип данных, `frozenset` - неизменяемый

# %%
set_3 = frozenset(['a', 'b', 'c', 'd', 'a', 'b', 'a'])
set_3
# Out:
# frozenset({'a', 'b', 'c', 'd'})

# %%
set_3.qwe('e')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-16ec1d3636b2> in <cell line: 1>()
# ----> 1 set_3.qwe('e')
#
# AttributeError: 'frozenset' object has no attribute 'qwe'

# %% [markdown]
# [Множества (set и frozenset)](https://pythonworld.ru/tipy-dannyx-v-python/mnozhestva-set-i-frozenset.html)

# %% [markdown]
# ### Циклы и ветвления

# %%
bremen_musicians = ['Кот', 'Пёс', 'Трубадур', 'Осёл', 'Петух']

# %% [markdown]
# #### Объявление и тело цикла

# %%
bremen_musicians
# Out:
# ['Кот', 'Пёс', 'Трубадур', 'Осёл', 'Петух']

# %%
for i in bremen_musicians: # объявление цикла
  print(i) # тело цикла
# Out:
# Кот
# Пёс
# Трубадур
# Осёл
# Петух

# %%
c = 0
for i in bremen_musicians: # объявление цикла
  print(f'Музыкант {c}: {i}') # тело цикла
  c += 1
# Out:
# Музыкант 0: Кот
# Музыкант 1: Пёс
# Музыкант 2: Трубадур
# Музыкант 3: Осёл
# Музыкант 4: Петух

# %%
for i, item in enumerate(bremen_musicians):
    print(f'Музыкант {i + 1}: {item}')
# Out:
# Музыкант 1: Кот
# Музыкант 2: Пёс
# Музыкант 3: Трубадур
# Музыкант 4: Осёл
# Музыкант 5: Петух

# %%
for i in range(1, 11):
  print(i)
  print('test')
# Out:
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test

# %%
for i in range(1, 11, 0):
  print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-3ce6f5b63515> in <cell line: 1>()
# ----> 1 for i in range(1, 11, 0):
#       2   print(i)
#
# ValueError: range() arg 3 must not be zero

# %% [markdown]
# #### Вложенные циклы

# %%
for i in range(3):
  for i, item in enumerate(bremen_musicians):
      print(f'Музыкант {i + 1}: {item}')
  print('*' * 20)
# Out:
# Музыкант 1: Кот
# Музыкант 2: Пёс
# Музыкант 3: Трубадур
# Музыкант 4: Осёл
# Музыкант 5: Петух
# ********************
# Музыкант 1: Кот
# Музыкант 2: Пёс
# Музыкант 3: Трубадур
# Музыкант 4: Осёл
# Музыкант 5: Петух
# ********************
# Музыкант 1: Кот
# Музыкант 2: Пёс
# Музыкант 3: Трубадур
# Музыкант 4: Осёл
# Музыкант 5: Петух
# ********************

# %% [markdown]
# #### Ветвления

# %%
a = 10

if a > 50:
  print('Больше 50')
else:
  print('Меньше или равно 50')

print('Конец')
# Out:
# Конец

# %%
var = '100500'

if type(var) is int:
  print('Это число')
  res = var * 2
else:
  print('Это не число!')
  res = None
# Out:
# Это не число!

# %%
print(res)
# Out:
# None

# %% [markdown]
# Литерал None в Python позволяет представить null переменную, то есть переменную, которая не содержит какого-либо значения. Другими словами, None – это специальная константа, означающая пустоту.

# %%
type(res)
# Out:
# NoneType

# %% [markdown]
# #### Множественные ветвления

# %%
var = '100500'

# %%
if type(var) is int:
  print('Это число')
  res = var * 2

if type(var) is str:
    print('Это строка')
    res = var + ' - строка!'

if type(var) is bool:
    print('Это логический тип')
    var = not var

print(res)
# Out:
# Это строка
# 100500 - строка!

# %%
if type(var) is int:
  print('Это число')
  res = var * 2

elif type(var) is str:
    print('Это строка')
    res = var + ' - строка!'

elif type(var) is bool:
    print('Это логический тип')
    res = not var

print(res)
# Out:
# Это строка
# 100500 - строка!

# %%
var = [100]

if type(var) is int:
  print('Это число')
  res = var * 2

elif type(var) is str:
    print('Это строка')
    res = var + ' - строка!'

elif type(var) is bool:
    print('Это логический тип')
    res = not var
else:
  print('Какой-то неизвестный тип...')
  res = None

print(res)
# Out:
# Какой-то неизвестный тип...
# None

# %%
var = 200

if type(var) is int:
  print('Это число')
  res = var * 2

elif type(var) is str:
    print('Это строка')
    res = var + ' - строка!'

elif type(var) is bool:
    print('Это логический тип')
    res = not var
else:
  print('Какой-то неизвестный тип...')
  res = None

print(res)
# Out:
# Это число
# 400

# %% [markdown]
# ### Функции

# %%
def print_test() -> None:
  print('test')

# %%
print_test()
# Out:
# test

# %%
def calc_sum(a: int, b: int) -> int:
  return a + b

calc_sum(a=1, b=2)
# Out:
# 3

# %%
def check_type(var):
  if type(var) is int:
    print('Это число')
    res = var * 2

  elif type(var) is str:
      print('Это строка')
      res = var + ' - строка!'

  elif type(var) is bool:
      print('Это логический тип')
      res = not var
  else:
    print('Какой-то неизвестный тип...')
    res = None

  return res

# %%
check_type('100500')
# Out:
# Это строка
# '100500 - строка!'

# %%
check_type(100500)
# Out:
# Это число
# 201000

# %%
check_type(False)
# Out:
# Это логический тип
# True

# %%
a = check_type([100])
# Out:
# Какой-то неизвестный тип...

# %%
type(a)
# Out:
# NoneType

# %%
for var in ['100500', 100500, False, [100]]:
  res = check_type(var)
  print(res)
# Out:
# Это строка
# 100500 - строка!
# Это число
# 201000
# Это логический тип
# True
# Какой-то неизвестный тип...
# None

# %%
def check_type(var):
  if type(var) is int:
    return 'Это число'
  elif type(var) is str:
    return 'Это строка'
  elif type(var) is bool:
     return 'Это логический тип'
  else:
    return 'Какой-то неизвестный тип...'

# %%
calc_sum('1', 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b803203fe244> in <cell line: 1>()
# ----> 1 calc_sum('1', 2)
#
# <ipython-input-3-ec3e5426bbdc> in calc_sum(a, b)
#       1 def calc_sum(a, b):
# ----> 2   return a + b
#       3
#       4 calc_sum(a=1, b=2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def calc_sum(a, b):
  res_1 = check_type(a)
  res_2 = check_type(b)
  if res_1 == res_2 == 'Это число':
    return a + b
  else:
    print('Какой-то тип не совпадает c int')
    return None

# %%
calc_sum(1, 2)
# Out:
# 3

# %%
calc_sum('100', 2)
# Out:
# Какой-то тип не совпадает c int

# %% [markdown]
# ### Классы

# %% [markdown]
# **Класс** — шаблон, с помощью которого удобно описывать однотипные объекты. В классе соержатся свойства, правила создания и поведение объекта.
#
# **Объект** — экземпляр, созданный на основе шаблона.
#
# **Атрибут** — поле, хранящее значение. Содержит свойства объекта.
#
# **Метод** — функция, связанная с классом. Описывает поведение или действия объекта.
#
# Пример класса - автомобили, его атрибутами будут: цвет, марка автомобиля, регистрационный номер.

# %%
class Auto:
  def __init__(self, model, color): # Инициализация объекта
    self.model = model
    self.color = color

  def run(self, speed):
    print(speed)
    self.speed = speed
    print(self.model)
    print('Автомобиль заведен')

  def stop(self):
    print('Автомобиль остановлен')

# %%
auto = Auto('BMW', 'red')
print(auto)

# %%
auto.run(12)
# Out:
# 12
# BMW
# Автомобиль заведен

# %%
auto.speed
# Out:
# 12

# %%
class Auto:
  def __init__(self, model, color):
    self.model = model
    self.color = color

  def run(self):
    print('Автомобиль заведен')

  def __str__(self): # Преобразование к строке str(obj)
    return f'{self.model} {self.color}'

# %%
auto = Auto('BMW', 'red')
print(auto)
# Out:
# BMW red

# %%
auto.run()
# Out:
# Автомобиль заведен

# %% [markdown]
# ### Обработка ошибок

# %%
'100' / 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-72726d0b0ddc> in <cell line: 1>()
# ----> 1 '100' / 100
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
100 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-42-e9e866a10e2a> in <cell line: 1>()
# ----> 1 100 / 0
#
# ZeroDivisionError: division by zero

# %%
def div(a, b):
  res = None
  ex = False
  try:
    res = a / b
  except TypeError:
    ex = True
    print('Похоже, вы используете несовместимые типы...')
  except:
    ex = True
    print('Ошибка')
  if not ex:
    ...
  return res

# %%
div(100, 10)
# Out:
# 10.0

# %%
div(100, 0)
# Out:
# Ошибка

# %%
div(100, '10')
# Out:
# Похоже, вы используете несовместимые типы...

# %%
def div(a, b):
  res = None
  try:
    res = a / b
  except TypeError:
    print('Похоже, вы используете несовместимые типы...')
  except ZeroDivisionError:
    print('На ноль делить нельзя!')
  else: # else выполняется, если исключения не было
    print('Все хорошо!')
  finally: # finally выполняет блок инструкций в любом случае, было ли исключение, или нет
    print('Выполнение программы завершено')
  return res

# %%
div(100, 10)
# Out:
# Все хорошо!
# Выполнение программы завершено
# 10.0

# %%
div(100, 0)
# Out:
# На ноль делить нельзя!
# Выполнение программы завершено

# %% [markdown]
# Вызов исключений

# %%
a = 25

if a > 50:
  print('Больше 50')
else:
  raise ValueError('Меньше или равно 50!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-8bec28f28785> in <cell line: 3>()
#       4   print('Больше 50')
#       5 else:
# ----> 6   raise ValueError('Меньше или равно 50!')
#
# ValueError: Меньше или равно 50!

# %% [markdown]
# ### Что еще почитать?
#
# [Программирование на языке Python: год 1](https://python-course.readthedocs.io/projects/year1/en/latest/index.html#)
#
# [Python: основы и применение](https://stepik.org/course/512/syllabus)
